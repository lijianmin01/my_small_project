# %%
import pandas as pd
import numpy as np

df = pd.read_csv('song_informations.csv',index_col=0)
df.head()
# Out:
#            song playtime subtitle        date
# singers
# 没挂机队        懒狗代   622.4万     3.9万   2020/9/12
# 姜云升        芸芸众生   242.9万     1.1万   2020/11/1
# 剁椒沙丁鱼战队  世界以痛吻我   273.3万     5764   2020/11/1
# 圣代         书院来信   546.7万     1.4万  2020/10/24
# 于贞          粒子们   575.9万     2.0万  2020/10/10

# %%
playtime = list(df['playtime'].values)
#playtime

# %%
# new_play_time = [if i[-1]=='万' float(i[:-1])*1000 for i in playtime]
new_play_time = []
for num in playtime:
    if num[-1]=='万':
        cnt = float(num[:-1])*1000
        new_play_time.append(int(cnt))
    else:
        new_play_time.append(int(num))

#new_play_time
print(len(new_play_time))
# Out:
# 105

# %%
date = list(df['date'].values)
len(date)
# Out:
# 105

# %%
song = list(df['song'].values)
len(song)
# Out:
# 105

# %%
song_playtimes = {'song':song,'playtime':new_play_time,'date':date}

date01 = pd.DataFrame(song_playtimes)

date01.to_csv("song_playtimes.csv",index=0)

# %%
df = pd.read_csv("song_playtimes.csv",index_col=0)
df
# Out:
#                         playtime        date
# song
# 懒狗代                       622400   2020/9/12
# 芸芸众生                      242900   2020/11/1
# 世界以痛吻我                    273300   2020/11/1
# 书院来信                      546700  2020/10/24
# 粒子们                       575900  2020/10/10
# Love in my pocket         340700   2020/9/26
# 向前                        187800  2020/10/31
# 反抗                        421200   2020/9/19
# We&nbsp;We                502300   2020/9/12
# 最后的晚安                     269600  2020/10/24
# 山顶洞人与夜航船                  178400  2020/10/31
# 飞奔向你                      259800   2020/11/1
# 早点早点                      264000   2020/9/19
# 听到了吗                      101000  2020/10/24
# 画                         418900   2020/8/23
# What do you want          150000  2020/10/31
# What is rap               126400   2020/11/1
# 来自世界的恶意                   286100   2020/8/29
# 那一首歌                      261399   2020/9/26
# 未接来电                      146700   2020/10/3
# 写给说唱新世代参赛选手的一封挑战书         124700  2020/10/10
# 给说唱新世代参赛选手的一封建议信          148100   2020/11/1
# 来自世界的恶意                   286100   2020/8/29
# 我不想死在20岁                  292700   2020/9/26
# 听到了吗                      101000  2020/10/24
# Real Life                 243400   2020/8/29
# 放肆爱                       277900   2020/9/26
# 成功的布鲁斯一夜                  139400  2020/10/24
# 风                         148500   2020/10/3
# What is rap               126400   2020/11/1
# ...                          ...         ...
# 快马加鞭                      124000  2020/10/24
# Ring Ring                 127500  2020/10/31
# 飞鸟                        338200   2020/9/12
# 都是我                        86800   2020/11/1
# 当他消失的那天                   106200  2020/10/17
# 把我最爱的文字读给你听                82200   2020/11/1
# 奥利奥少年                     195000   2020/8/23
# 在路上                        96700  2020/10/24
# Hometown                   99600   2020/10/3
# 年少的你可曾想过                  136700  2020/10/24
# Harbour                   187400   2020/10/3
# Old mountain road         145600   2020/9/26
# 而立                        743300   2020/8/23
# 有个霸王                      223200   2020/9/12
# 与众不同                      135700   2020/9/26
# 小兔子乖乖                     224200   2020/8/23
# 倚老卖老                      123100  2020/10/24
# 做个哑巴                      187700   2020/9/19
# Hey&nbsp;U                179600   2020/9/12
# 老刘                        142000   2020/10/3
# 逃离这个星球                     78500  2020/10/10
# 交代                         65500  2020/10/24
# 拿起放下                       63500  2020/10/31
# 猴子                         80300   2020/9/26
# Get The Power              73900  2020/10/10
# Superfly Producer Life     63500  2020/10/24
# 规律人生                       61900  2020/10/24
# HALO！                      72000  2020/10/10
# 山城男人                       73900   2020/10/3
# FIGHT！                     53600  2020/10/31
#
# [104 rows x 2 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 104 entries, 懒狗代 to FIGHT！
# Data columns (total 2 columns):
# playtime    104 non-null int64
# date        104 non-null object
# dtypes: int64(1), object(1)
# memory usage: 2.4+ KB

# %%
# 日期从字符串 转成日期格式
import datetime

def t_datetime(date):
    return datetime.datetime.strptime(date,"%Y-%m-%d")

# 计算两个日期之间相隔的天数
def get_day_nums(begin_date,end_date):
    begin_date = datetime.datetime.strptime(begin_date, "%Y/%m/%d")
    end_date = datetime.datetime.strptime(end_date,"%Y-%m-%d")
    
    # 最后一天也算数
    return int((end_date - begin_date).days)+1

# print(get_day_nums('2020-08-22','2021-02-14'))

# %%
# 获取从2020-08-22   2021-02-14

#获取两个日期间的所有日期
import datetime
def getEveryDay(begin_date,end_date):
    date_list = []
    begin_date = datetime.datetime.strptime(begin_date, "%Y-%m-%d")
    end_date = datetime.datetime.strptime(end_date,"%Y-%m-%d")
    while begin_date <= end_date:
        date_str = begin_date.strftime("%Y-%m-%d")
        date_list.append(date_str)
        begin_date += datetime.timedelta(days=1)
    return date_list

#print(getEveryDay('2016-01-01','2017-05-11'))

date_list = getEveryDay('2020-08-22','2021-02-14')

# date_list

# %%
# 制作最后的总表
fin_table = []
# 添加日期
fin_table.append(date_list)

# %%
playtime = list(df['playtime'].values)
date = list(df['date'].values)

for i in range(len(date)):
    # 获取播放日期与今天的日期相差天数
    after_days = get_day_nums(date[i],'2021-02-14')
    # 每次累加的天数
    ## 估计每天增长的天数是一样的
    plus_num = int(playtime[i]/after_days)
    # 根据总表的数据添加数据
    every_song_date_cnt = []
    # 该歌曲是否已经被播放
    flag = 0
    play_sum = 0
    for every_date_index in range(len(date_list)):
        if (flag==0):
            # 是否到播出日期
            ## datetime.datetime.strptime(begin_date, "%Y/%m/%d")
            ### if(t_datetime(date_list[every_date_index])>=date[i]):
            if(t_datetime(date_list[every_date_index])>=datetime.datetime.strptime(date[i], "%Y/%m/%d")):
                flag=1
                play_sum += plus_num
                every_song_date_cnt.append(play_sum)
            else:
                every_song_date_cnt.append(0)
        else:
            play_sum += plus_num
            every_song_date_cnt.append(play_sum)
    
    # 将该歌曲播放变化量写入总表
    fin_table.append(every_song_date_cnt)
    
fin_table = np.array(fin_table).T

fin_table = pd.DataFrame(fin_table,columns=song)
    
fin_table.to_csv("finnally_table.csv",index=0)
